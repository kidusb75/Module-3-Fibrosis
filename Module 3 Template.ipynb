# %% [markdown]
# ## Module_3: Fibrotic Disease
#
# ## Team Members:
# *Kidus Belay & Eunela Manzano*
#
# ## Project Title:
# *Predicting Idiopathic Lung Fibrosis Severity Using Image-Based Interpolation Across Biopsy Depths*

# %% [markdown]
# ## Project Goal:
# This project seeks to analyze lung tissue images to determine how the extent of fibrosis changes with depth into the lung. By quantifying the percentage of white pixels at different depths, we aim to develop an interpolation-based model that predicts fibrosis at depths where direct measurements are unavailable. This helps simulate how a medical device could estimate fibrosis without requiring biopsies at every depth.

# %% [markdown]
# ## Disease Background:
#
# * Prevalence & incidence
#
#     Pulmonary fibrosis is a chronic lung disease that affects millions of people worldwide, with Idiopathic Pulmonary Fibrosis (IPF) being the most common and well-studied form. Globally, pulmonary fibrosis is estimated to affect approximately 3 to 5 million people. The prevalence of IPF specifically is about 13 to 20 cases per 100,000 individuals, with the United States having an estimation between 100,000 and 200,000 people that are currently living with the disease. It's more common in older adults, particularly those over the age of 60, and occurs more frequently in men than in women (Meltzer & Noble, 2008; MedlinePlus Genetics, 2020).
#
#     In terms of incidence, IPF is considered a rare disease but continues to be diagnosed more frequently. Globally, there are about 3 to 9 new cases per 100,000 people each year, and in the United States, this corresponds to approximately 30,000 to 40,000 new cases annually. The rise in new cases is likely due to an aging population, improved ability to diagnose the disease, and increased awareness among healthcare providers (Meltzer & Noble, 2008; MedlinePlus Genetics, 2020).
#
#
#
# * Risk factors (genetic, lifestyle)
#
#     The likelihood of developing idiopathic pulmonary fibrosis (IPF) rises with age, particularly in individuals in their 60s and 70s. Men are more commonly affected than women, and lifestyle habits such as smoking can further elevate the risk. A family history of IPF can also increase risk, as having a parent or sibling with the condition makes one more susceptible. Furthermore, specific genetic mutations in over ten different genes have been associated with a greater chance of developing the disease (National Heart, Lung, and Blood Institute, 2022).
#
# * Symptoms
#
#     Idiopathic pulmonary fibrosis (IPF) most often causes shortness of breath that slowly gets worse, beginning with activity and eventually happening even when at rest, and a dry cough that can occur frequently and be difficult to control. Other symptoms may include muscle and joint aches, clubbing of the fingers or toes where the tips become widened and rounded, severe fatigue, unintentional weight loss, a general feeling of illness, and fast, shallow breathing (National Heart, Lung, and Blood Institute, 2022).
#
#
# * Standard of care treatment(s)
#
#     The standard approach to managing pulmonary fibrosis aims to slow the progression of the disease, ease symptoms, and enhance quality of life. Core treatment usually includes antifibrotic drugs like nintedanib or pirfenidone, which help limit further lung scarring. Patients who experience low oxygen levels may require supplemental oxygen to support breathing and daily activities. Pulmonary rehabilitation, which incorporates exercise, breathing exercises, and patient education, is recommended to preserve lung function and overall well-being. Additional care includes lifestyle modifications such as smoking cessation, avoiding lung irritants, and maintaining good nutrition, along with symptom management for cough or acid reflux. For patients with advanced or progressive disease, lung transplantation may be considered when standard therapies are no longer effective (Temple Health, 2022)
#
#
# * Biological mechanisms (anatomy, organ physiology, cell & molecular physiology)
#
#     Lung fibrosis, including idiopathic pulmonary fibrosis (IPF), happens when the lungs gradually develop excess scar tissue, which makes it harder for them to work properly. Normally, the lungs are made up of branching airways and tiny air sacs called alveoli, where oxygen passes into the blood and carbon dioxide leaves. The walls of the alveoli are very thin and made of alveolar epithelial cells (type I and II) and small blood vessels. Type I cells cover most of the alveoli and help gases move efficiently, while type II cells produce surfactant to keep the lungs open and can repair the alveolar lining after injury. When these cells are repeatedly damaged by infections, toxins, or unknown causes, the structure of the lungs becomes abnormal and scar tissue starts to build up (Zhang, Y., & Wang, J., 2023).
#
#     Normally, after a lung injury, the body triggers inflammation to heal the tissue. In lung fibrosis, however, this process becomes uncontrolled. Immune cells and injured lung cells release signals, especially transforming growth factor‑β (TGF‑β), which activate fibroblasts. These fibroblasts turn into myofibroblasts, cells that produce large amounts of extracellular matrix (ECM), including collagen. Too much ECM makes the lungs stiff and thickens the walls of the alveoli, which reduces lung compliance and makes it harder for oxygen to enter the blood (Agarwal, A. K., & Huda, N., 2023).
#
#     At the cellular level, the problem is that lung cells cannot repair themselves normally. Some alveolar cells die, while others release chemicals that encourage fibroblasts to grow and produce more ECM. Processes like epithelial‑to‑mesenchymal transition (EMT) may also convert some epithelial cells into fibroblast‑like cells. Key signaling pathways, such as TGF‑β/Smad and Wnt/β‑catenin, drive this abnormal cell activity and further promote scarring (Grafanaki et al., 2025).
#
#     Finally, a major issue in lung fibrosis is the failure to resolve the scar tissue. In healthy repair, fibroblasts eventually stop producing ECM and die off, and enzymes break down excess matrix. In fibrotic lungs, this does not happen. Myofibroblasts remain active, ECM continues to accumulate, and the lung tissue becomes permanently stiff and thickened. This structural change causes the main symptoms of fibrosis: shortness of breath, reduced exercise tolerance, and low blood oxygen (Zhang, Y., & Wang, J., 2023).

# %% [markdown]
# ## Data-Set:
# *Describe the data set(s) you will analyze. Cite the source(s) of the data -- in this case, these data have not yet been published and they are "hot off the press", having been recently generated by the Peirce-Cottler Lab in collaboration with the Kim Lab (https://uvahealth.com/findadoctor/John-Kim-1407155682) in the Division of Pulmonary and Critical Care at UVA. So the proper way to cite these data is:
#
# Unpublished data was collected by the Peirce-Cottler Lab (Dept. of Biomedical Engineering) and Kim Lab (Division of Pulmonary and Critical Care) at the University of Virginia School of Medicine. The data was derived using a Bleomycin-induced Lung Injury Model, a standard experimental approach where the antibiotic Bleomycin is used to simulate the progression of Idiopathic Pulmonary Fibrosis (IPF) in mice. Following a three-week induction period, lung tissue from the upper, middle, and lower lobes was digitally imaged. The resulting dataset includes 78  images captured at specific biopsy depths. To quantify the severity of the disease, we analyzed these images to measure the percentage of white pixels, a computational proxy for fibrotic collagen deposition—relative to the total tissue area. All depth measurements are recorded in microns (µm).

# %%
# Below is the code for my Module 3 Assigment, followed up with the data analysis. 
# Had difficulty with interting the code into the Jupyter Notebook, but I was able to get it to work in this format. 

'''Module 3: count black and white pixels and compute the percentage of white pixels in a .jpg image and extrapolate points'''

# 2: Generative AI (Gemini and Claude AI): Suggestion for import statements that can make the code more efficient and cleaner.  
    # import os  # Useful for handling file paths and getting clean filenames for the CSV.
    # Furthermore, elements of the code such as understanding certian functions and diagnosing errors were instances where AI was utilized to help the team understand the code better, especially in cases where the generative model put out a more efficient way to do something (like using np.count_nonzero instead of nested for loops to count pixels, which is much faster); 
    # Lastly, occasionally needed AI to understand why and help comment some specific code lines for better clarity and understanding, but all final implementation and understanding was done by the team. 

import os # added for efficiency: OS for robust file path handling
from termcolor import colored   # used only to print colored text in terminal
import cv2                      # OpenCV library for image processing
import numpy as np              # numerical operations (arrays, sums, etc.); # NumPy for vectorized (fast) array math
import pandas as pd             # used to create csv file 
import time                     # used on 03/24/2026 for inclass activity: computing the time it takes to run the code with and without vectorization for counting pixels.


# Load the images you want to analyze -- specific file paths depend from computer or access method: 
# the primary images that we ended up analyzing are sourced from the images foleder in the Module-3-Fibrosis folder, but you can also use the full file paths to load the images if you want.
    # The 78 image are provided by the instructor. 
# Load the images you want to analyze -- specific file paths depend from computer or access method: 
filenames = [ 
    r"C:\Users\kidus\OneDrive\Desktop\Computational BME\Module 03\Module-3-Fibrosis\images\MASK_Sk658 Llobe ch010039.jpg",  # 15 (Initial)
    r"C:\Users\kidus\OneDrive\Desktop\Computational BME\Module 03\Module-3-Fibrosis\images\MASK_Sk658 Llobe ch010030.jpg",  # 200 (NEWly added)
    r"C:\Users\kidus\OneDrive\Desktop\Computational BME\Module 03\Module-3-Fibrosis\images\MASK_Sk658 Llobe ch010032.jpg",  # 500 (Initial)
    r"C:\Users\kidus\OneDrive\Desktop\Computational BME\Module 03\Module-3-Fibrosis\images\MASK_SK658 Llobe ch010067.jpg",  # 1500 (NEWly added)
    r"C:\Users\kidus\OneDrive\Desktop\Computational BME\Module 03\Module-3-Fibrosis\images\MASK_Sk658 Llobe ch010146.jpg",  # 2000 (Initial)
    r"C:\Users\kidus\OneDrive\Desktop\Computational BME\Module 03\Module-3-Fibrosis\images\MASK_SK658 Slobe ch010147.jpg",  # 3000 (NEWly added)
    r"C:\Users\kidus\OneDrive\Desktop\Computational BME\Module 03\Module-3-Fibrosis\images\MASK_SK658 Slobe ch010134.jpg",  # 4500 (NEWly added)
    r"C:\Users\kidus\OneDrive\Desktop\Computational BME\Module 03\Module-3-Fibrosis\images\MASK_SK658 Slobe ch010112.jpg",  # 5500 (Initial)
    r"C:\Users\kidus\OneDrive\Desktop\Computational BME\Module 03\Module-3-Fibrosis\images\MASK_SK658 Slobe ch010126.jpg",  # 6800 (NEWly added)
    r"C:\Users\kidus\OneDrive\Desktop\Computational BME\Module 03\Module-3-Fibrosis\images\MASK_SK658 Slobe ch010119.jpg",  # 8000 (Initial)
    r"C:\Users\kidus\OneDrive\Desktop\Computational BME\Module 03\Module-3-Fibrosis\images\MASK_SK658 Slobe ch010136.jpg",  # 9200 (NEWly added)
    r"C:\Users\kidus\OneDrive\Desktop\Computational BME\Module 03\Module-3-Fibrosis\images\MASK_SK658 Slobe ch010092.jpg",  # 10000 (Initial)
]

# # For partner: use relative paths so it works for them. 
# # Use relative paths so it works for your partner too!
# filenames = [
#     r"images/MASK_SK658 Llobe ch010039.jpg",
#     r"images/MASK_SK658 Llobe ch010032.jpg",
#     r"images/MASK_SK658 Slobe ch010146.jpg",
#     r"images/MASK_SK658 Slobe ch010112.jpg",
#     r"images/MASK_SK658 Slobe ch010119.jpg",
#     r"images/MASK_SK658 Slobe ch010092.jpg"
# ]

# Enter the depth of each image (in the same order that the images are listed above; you can find these in the .csv file provided to you which is tilted: "Filenames and Depths for Students")
# The depth values are in microns, and they represent the depth at which each image was taken. This information is crucial for analyzing the relationship between depth and the percentage of white pixels in the images, which can be important for understanding tissue characteristics in a biomedical context.
# More specifically, these are the depth values chronologically listed immages above, from shallowest to deepest within the mice lungs; and the team did this collection method instead of choosing images at complete random becasue we wanted to have a range of depths represented in our data, which can help us see trends and patterns in the percentage of white pixels as depth increases. 
# By including images from various depths, we can better understand how the tissue characteristics change with depth, which is important for our analysis of fibrosis in the lungs.

# Updated depths list (in microns) formatted to match the order of the images above -- 6 original images + 6 newly added images for better interpolation and extrapolation.
depths = [15, 200, 500, 1500, 2000, 3000, 4500, 5500, 6800, 8000, 9200, 10000]
results = []
white_percent_list = []

print(colored("Starting Image Analysis...", "yellow"))

# 2. Process Images 

# Load ALL images into memory BEFORE starting the timer
images_loaded = [cv2.imread(f, 0) for f in filenames]

# Start timer for efficiency testing (before for loop) 
start_time = time.time()  # Start timer for efficiency testing (before for loop) 
print (colored("Processing images...", "yellow"))

# this part of the code is the most computationally intensive part. 
#   Essentially, we want to time it to see how long it takes with and without vectorization. The for loop iterates through each image, counts the white and black pixels, calculates the percentage of white pixels, and stores the results in a list of dictionaries. 
# The use of NumPy's vectorized operations (like np.count_nonzero) makes this process much faster than iterating through each pixel manually.
for img, filename, depth in zip(images_loaded, filenames, depths):
    # img is directly available — no .index() lookup needed
    white_count = np.count_nonzero(img > 127)
    total_pixels = img.size
    black_count = total_pixels - white_count
    white_percent = (white_count / total_pixels) * 100
    white_percent_list.append(white_percent) # adding the white percent to a list for later use in interpolation and plotting
    clean_name = os.path.basename(filename) # os.path.basename() extracts just the filename from the full path, which is cleaner for the CSV output. This is more robust than manually splitting the string, as it works regardless of the operating system or path format.
    results.append({
        'Filename': clean_name,
        'Depth': depth,
        'White_Pixels': white_count,
        'Black_Pixels': black_count,
        'White_Percent': round(white_percent, 2)
    })

end_time = time.time()  # End timer for efficiency testing (before printing results) -- faster time --- averaging 0.00 to 0.01 seconds with vectorization, compared to 1.5 to 2 seconds initially without vectorization (when counting pixels with nested for loops instead of np.count_nonzero). This shows that vectorization is much more efficient for this type of pixel counting task.
total_time = end_time - start_time  # End timer for efficiency testing (after for loop)


# REQUIRED PRINT FORMAT FOR EACH IMAGE (for loop above):
print(colored(clean_name, "red"))
print(f"White pixels: {white_count}")
print(f"Black pixels: {black_count}")
print(f"Percent white pixels: {white_percent:.2f}%")
print(f"Depth: {depth} microns\n")

# 3. CSV WRITING SUBROUTINE
# Using Pandas to create the CSV is more efficient than the standard CSV library.
# It automatically handles the headers and table structure.
df = pd.DataFrame(results)
df.to_csv('Percent_White_Pixels.csv', index=False)

print(colored("Success: 'Percent_White_Pixels.csv' has been created.", "green")) 

print(colored(f"Total processing time: {total_time:.2f} seconds", "cyan"))  # Print total time taken for efficiency testing

# (End of assigned efficiency section - code below line 93 ignored)


# LECTURE 2: Interpolation (and possibly extrapolation)
#  ---reformated the orignial code from both interpolation_example.py and the code that we made intally for interpolation (above in comments) in main_example.py to make it more efficient and cleaner, and to add the quadratic and cubic interpolation options for better comparison of the fitting models; Wanted to also compare the errors more easily. 
# Interpolate a point: given a depth, find the corresponding white pixel percentage

import matplotlib.pyplot as plt
from scipy.interpolate import interp1d

# interpolation instruction for the user to input a depth value for interpolation. 
#   The input function prompts the user to enter a depth in microns, which is then converted to a float for use in the interpolation process. 
interpolate_depth = float(input(colored(
"Enter the depth at which you want to interpolate a point (in microns): ", "yellow")))

x = depths
y = white_percent_list

# You can also use 'quadratic', 'cubic', etc.
# This is the interpolation function that will allow us to find the corresponding y value (percentage of white pixels) for any given x value (depth) within the range of our data. The 'kind' parameter specifies the type of interpolation, and in this case, we are using linear interpolation.
    # Essentially, the linear algebra side of our assigment: we are solving for the coefficients of a linear equation that best fits our data points, and then using those coefficients to compute the corresponding y value for a specific x value (the depth we want to interpolate at). The interp1d function from SciPy simplifies this process by creating an interpolation function that we can call with any x value to get the corresponding y value based on our original data points.
    # This interp1d function can also handle more complex cases such as quadratic or cubic interpolation, which can provide a better fit for data that is not well represented by a straight line. By changing the 'kind' parameter, we can easily switch between different types of interpolation to see which one best fits our data.

# We calculate the values for all three fitting methods to compare the fibrosis level predictions
i_linear = interp1d(x, y, kind='linear')
i_quadratic = interp1d(x, y, kind='quadratic')
i_cubic = interp1d(x, y, kind='cubic')

# calculating the interpolated points for all three fitting methods to compare the fibrosis level predictions: linear, quadratic, and cubic interpolation. This allows us to see how the predicted percentage of white pixels (which is an indicator of fibrosis level) changes based on the type of interpolation used, and to compare the accuracy of each method against the actual data points we have.
interpolate_point_lin = i_linear(interpolate_depth)
interpolate_point_quad = i_quadratic(interpolate_depth)
interpolate_point_cub = i_cubic(interpolate_depth)

# Identify the nearest actual data point for comparison and calculate the percent error
# Identify the nearest actual data point for comparison
closest_depth = min(depths, key=lambda d: abs(d - interpolate_depth))
closest_val = white_percent_list[depths.index(closest_depth)]

# Calculate the percent error for each interpolation method relative to this real image
error_lin = abs(interpolate_point_lin - closest_val) / closest_val * 100
error_quad = abs(interpolate_point_quad - closest_val) / closest_val * 100
error_cub = abs(interpolate_point_cub - closest_val) / closest_val * 100

print(colored(f"\n--- VALIDATION AGAINST REAL DATA ---", "yellow"))
print(f"User Input Depth: {interpolate_depth} microns")
print(f"Nearest Real Image: {closest_depth} microns (Measured Fibrosis: {closest_val:.2f}%)")
print("-" * 50)
print(f"Linear Prediction:    {interpolate_point_lin:.2f}% (Error: {error_lin:.2f}%)")
print(f"Quadratic Prediction: {interpolate_point_quad:.2f}% (Error: {error_quad:.2f}%)")
print(f"Cubic Prediction:     {interpolate_point_cub:.2f}% (Error: {error_cub:.2f}%)")
print("-" * 50)
# generate smooth lines for Plot #2 to show the fitting models through the interpolated point
x_smooth = np.linspace(min(depths), max(depths), 500)

depths_i = depths[:]
depths_i.append(interpolate_depth)
white_percents_i = white_percent_list[:]
white_percents_i.append(interpolate_point_lin) # default list append for legacy structure


# make two plots: one that doesn't contain the interpolated point, just the data calculated from your images, and one that also contains the interpolated point (shown in red)
# Create a figure window containing 2 stacked plots (2 rows, 1 column).
# 'fig' = the whole window. 'axs' = array of the two plot panels.
# axs[0] is the top plot, axs[1] is the bottom plot.
fig, axs = plt.subplots(2, 1, figsize=(8, 10))

# PLOT #1 (top): raw measured data only 
# Plot the 6 real data points. scatter() draws individual dots.
# Note: linestyle='-' does nothing on scatter() — that's a plot() argument.
axs[0].scatter(depths, white_percent_list, marker='o', color='blue')
axs[0].set_title('Plot of depth of image vs percentage white pixels')
axs[0].set_xlabel('depth of image (in microns)')
axs[0].set_ylabel('white pixels as a percentage of total pixels')
axs[0].grid(True)   # adds background gridlines for readability

# PLOT #2 (bottom): same data + the interpolated point 
# depths_i and white_percents_i are copies of the original lists
# with the interpolated point appended as the 7th entry.
axs[1].scatter(depths_i[:-1], white_percents_i[:-1], marker='o', color='blue') # plot original 6

# We add the line connections specifically to the plot containing the interpolated point to visualize the fit
axs[1].plot(x_smooth, i_linear(x_smooth), label='Linear', color='green', linestyle='--', alpha=0.7)
axs[1].plot(x_smooth, i_quadratic(x_smooth), label='Quadratic', color='orange', linestyle=':', alpha=0.7)
axs[1].plot(x_smooth, i_cubic(x_smooth), label='Cubic', color='purple', alpha=0.5)

axs[1].set_title(
    'Plot of depth of image vs percentage white pixels with interpolated point (in red)')
axs[1].set_xlabel('depth of image (in microns)')
axs[1].set_ylabel('white pixels as a percentage of total pixels')
axs[1].grid(True)

# Re-plot just the LAST item in the list (the interpolated point) in red.
# depths_i[-1] is a cleaner way to write depths_i[len(depths_i)-1] — same thing.
# s=100 makes the dot larger so it stands out visually.
# We plot the cubic interpolation as our highlighted red point
axs[1].scatter(interpolate_depth, interpolate_point_cub,
               color='red', s=100, label='Highlighted point', zorder=5)

# Automatically adjusts spacing between the two plots so
# titles and axis labels don't overlap each other.
plt.tight_layout()
axs[1].legend()

# Render and display the figure window on screen.
plt.show()
# Out:
# Starting Image Analysis...
# Processing images...
# MASK_SK658 Slobe ch010092.jpg
# White pixels: 328891
# Black pixels: 3865413
# Percent white pixels: 7.84%
# Depth: 10000 microns
#
# Success: 'Percent_White_Pixels.csv' has been created.
# Total processing time: 0.01 seconds
#
# --- VALIDATION AGAINST REAL DATA ---
# User Input Depth: 2000.0 microns
# Nearest Real Image: 2000 microns (Measured Fibrosis: 3.48%)
# --------------------------------------------------
# Linear Prediction:    3.48% (Error: 0.00%)
# Quadratic Prediction: 3.48% (Error: 0.00%)
# Cubic Prediction:     3.48% (Error: 0.00%)
# --------------------------------------------------

# %% [markdown]
# ## Data Analysis:
# *Describe how you analyzed the data. This is where you should intersperse your Python code so that anyone reading this Jupyter notebook can run your code to perform the analysis that you did, generate your figures, generate your .csv file, etc.). Show your graphs here, which should have proper labeles (e.g., x- and y-axes labels). Each graph you present should be thoroughly described by a caption so reader understands the data, why you are presenting it, and the main conclusion fromt the data.*
#
# To develop and test our interpolation algorithm, we extracted data from 6 images sampled from the larger 78-image dataset. By focusing on this subset, we were able to precisely map the 'White Pixel Percentage' at key interval depths (micrometers): 15, 500, 2000, 5500, 8000, and 10,000. This sampling strategy allowed us to verify our computational pipeline before potentially scaling the analysis to the entire dataset. Each image was loaded imaged using OpenCV tool(image processing library), and it was interpreted under grayscale, void of any color. For the purposes of constraining analysis to detecting fibrosis, we classified a pixel value exceeding 127 to be classified as fibrotic; this under the scale of image pixels with 0 (black, health tissue) to 255 (white fibrotic tissue). Afterward, the aggregate white pixel count were divided by the total pixel count to obtain the white pixel percentages: each image has a specific depth with unique white pixel (fibrosis) percentage. These results are continiously saved to CSV file for refrence. As prompted by Intuitive, the medical device company, the whole purpose of the algorathm we made was to that these images serve as a base to make scientific, accurate guesses of lung fibrosis levels at varying depths via interpolation (for data contained within our image subset). To achieve this goal, we untilized the interp1d function, which is aided by principles of linear algebra, to solve for specific coefficent values that will then be mapped out to different, chosen polynomial functions: linear, quadratic, and cubic. These coefficent values are then mapped out with these polynomial functions to help predict fibrosis at a user-inputed depth via interpolation. We later analyzed the best polynomial function that best estimates and assesses the trend provided by the 12 chosen images (6 primary chosen pictures and 6 additional pictures).
#
#
# Inital subset of images (6 images -- chosen with specficity and not randomness; wanted to make a representative analysis from the start):
# - images/MASK_SK658 Llobe ch010039.jpg
# - images/MASK_SK658 Llobe ch010032.jpg
# - images/MASK_SK658 Slobe ch010146.jpg
# - images/MASK_SK658 Slobe ch010112.jpg
# - images/MASK_SK658 Slobe ch010119.jpg
# - images/MASK_SK658 Slobe ch010092.jpg
#
# Other images:
# - Added 6 more images to the data set to fill gaps present within the data and make it more complete for analysis: Cut down standard deviation/spread of the data from 3600 micrometers to 386 micrometers for depth between points.
#     - images/MASK_Sk658 Llobe ch010030.jpg
#     - images/MASK_SK658 Llobe ch010067.jpg
#     - images/MASK_SK658 Slobe ch010147.jpg
#     - images/MASK_SK658 Slobe ch010134.jpg
#     - images/MASK_SK658 Slobe ch010126.jpg
#     - images/MASK_SK658 Slobe ch010136.jpg
#
# Graph descriptions explanation:
#
# - Figure #1 (pre-intrapolation): Percent of white pixels (fibrosis) plotted againt image depth for the 6 sampled images.
#     - Observed and validated our hypothesis that increased depth equating greater fibrosis, as indicated by the increasing depth values and increasing fibrosis percentages. This was in the inital phase of the project with only 6 images analyzed, however.
#
#
#
# - Figure #3 (post-intrapolation): Percent of white pixels (fibrosis) plotted againt image depth for 12 sampled images (additional 6 images injected into the data to account for spacing present between point values). Once all points are present throughout graph, the SciPy library's function Interp1d is utilized to apply linear, quadratic, and cubic fitting throughout the values for fitting. Afterwards, user input for data value interpolated, which displayed as a red point, is then compared to the 12 image subset. Specifically, the interpolated image has it hypothesized percentage value for fibrosis compared to the nearest real data set value; this error is then calculated between linear, quadratic, and cubic fitting for each of their's respective accuracy shown by their error percentages relative to the nearest real image's actaul fibrosis level.
#
#
# The code for the program is above Data Analysis block segement.

# %% [markdown]
# ## Verify and validate your analysis:
# *Describe how you checked to see that your analysis gave you an answer that you believe (verify). Describe how your determined if your analysis gave you an answer that is supported by other evidence (e.g., by comparing your analysis to a published paper).*
#
# We verified our analysis by checking the generated .csv file to ensure each row contained the correct filename and corresponding depth/pixel data. We also plotted the data to confirm that it followed the expected biological trend: fibrosis generally increases as you look deeper into the lung.
# This finding was later verified by scientific paper published by Maxwell L. Smith, M.D.: In "The histologic diagnosis of usual interstitial pneumonia of idiopathic pulmonary fibrosis. Where we are and where we need to go", the author agrees with the scientific trend of fibrosis increasing with depth in IPF, citing the cause as the disease starting at the lung depest edges and spreading inward, and those outer regions are the most repeatedly injured and most poorly repaired.
#
# To validate our interpolation results, we compared the predicted fibrosis percentage at a chosen depth to an actual measurement from the Filenames and Depths for Students.csv dataset, specifically our 12 chosen images. For each interpolated depth, we identified the real image taken at the closest matching depth and compared its measured white‑pixel percentage to our interpolated value. This allowed us to quantify the interpolation error and evaluate the accuracy of the linear, quadratic, and cubic fits.

# %% [markdown]
# ## Conclusions and Ethical Implications:
# *Think about the answer your analysis generated, draw conclusions related to your overarching question, and discuss the ethical implications of your conclusions.*
#
# From our data analysis and graphical illustrations, we can draw the conclusion that Fibrosis does not spread at a constant, uniform rate, instead preffering to cluster around specific regions and varying at different depths; this is also proved by how some regions of data observe a strong linear relationship for data-fitting, while other variable regions prefer quadratic or cubic polynomials for interpolation and fitting approximations. In the design of the device, our advice is to consider utilizing new technology to take biopsies more frequently on the upper levels of the lung because the data seems to indicate more predictive. However, for the deeper depths of the lung, we propose to also utilze the future impelemtation of the technollogy by Intuitive to have flexability as a high priority quality in development. This is becasue at specific, deeper depths, the interpolation is not as accurate with high data varaibility and unknowns present; thus, to study deeper parts of the lung's lobes, more precise biopsies and data is requried. Lastly, the software should use cubic math for curved/complex regions and linear math for uniform regions to provide the most accurage fibrosis map.
#
# Ethical considerations:
# - Our data fitting has still some error in calculation: investment into research for better math models allow us to get more information from fewer biopsies, reducing both number of animals needed for medical research and improve the predictive sampling (interpolation) in data analysis.
# - Image analysis was only constrained to white pixel count, which was rather set at 127 brightness level -- a possible source of error that could alienate some values and be a source of bias
# - Our model should not replace trained medical professionals: the preditive algorithim for fibrosis levels at different lobes of the lungs should not be final judge for live-saving medicine or other theraputic/surgical interventions -- decisions should be made by a team of clinicans who could utilize this algorithm as another tool.
#
# 3. Ethical ImplicationsAccuracy vs. Treatment: A 5% calculation error in the code could mean the difference between a patient receiving life-saving medicine or being sent home.The 3Rs (Reduction): .Algorithmic Bias: The "White Pixel" threshold is set by humans; engineers have an ethical duty to ensure this setting doesn't lead to systematic under-diagnosis.

# %% [markdown]
# ## Limitations and Future Work:
# *Describe the limitations of your project. If you had more time to work on this, what would you do to explore further or refine your analysis?*
#
# A primary limitation of this project is the relatively small number of data points used for interpolation, which may not capture the non-linear biological complexity of human lung tissue. Furthermore, mouse models are approximations of human disease and may not perfectly replicate the spatial distribution of human IPF. Lastly, due to the diffrences in nature (composition of lung tissue cells and movement of bipedal vs quadroboic movement affects the lungs) and other acting forces (gravity), there may be limitation present of how direcly results gathered applies direclty to human biology.
#
# If given more time, we would implement automated image segmentation using convolutional neural networks (CNNs) to distinguish between collagen and other bright artifacts (e.g., shadows or blood vessels). Furthermore, a more critical image analysis technique should be deployed instead of always relying on image brightness, which could be a source of significant error. We would also explore spline interpolation on a larger dataset (all 78 images) in addition to other predictive computational methods (Artifical Intellegence) to create a more robust predictive curve for the entire lung lobe.

# %% [markdown]
# ## References:
# *You can use any format you like but provide the citations for facts that you referenced in this project notebook.*
#
# Agarwal, A. K., & Huda, N. (2023, August 8). Interstitial pulmonary fibrosis. In StatPearls. StatPearls Publishing. https://www.ncbi.nlm.nih.gov/books/NBK557765
#
# Grafanaki, K., Maniatis, A., Sotiropoulou, V., Pasmatzi, E., & Tzouvelekis, A. (2025). Fibrotic Disease of the Skin and Lung: Shared Pathways, Environmental Drivers, and Therapeutic Opportunities in a Changing Climate. International Journal of Molecular Sciences, 26(17), 8394. https://doi.org/10.3390/ijms26178394
#
# Meltzer, E. B., & Noble, P. W. (2008). Idiopathic pulmonary fibrosis. Orphanet journal of rare diseases, 3, 8. https://doi.org/10.1186/1750-1172-3-8
#
# MedlinePlus Genetics. (2020, July 1). Idiopathic pulmonary fibrosis. U.S. National Library of Medicine. https://medlineplus.gov/genetics/condition/idiopathic-pulmonary-fibrosis/
#
# National Heart, Lung, and Blood Institute. (2022, March 24). Idiopathic pulmonary fibrosis. U.S. National Institutes of Health. https://www.nhlbi.nih.gov/health/idiopathic-pulmonary-fibrosis
#
# Temple Health. (2022, August 26). Pulmonary fibrosis treatment options. Temple Health. https://www.templehealth.org/services/conditions/pulmonary-fibrosis/treatment-options
#
# Zhang, Y., & Wang, J. (2023). Cellular and Molecular Mechanisms in Idiopathic Pulmonary Fibrosis. Advances in respiratory medicine, 91(1), 26–48. https://doi.org/10.3390/arm91010005
#
# Verification for data analysis:
# - Smith M. L. (2022). The histologic diagnosis of usual interstitial pneumonia of idiopathic pulmonary fibrosis. Where we are and where we need to go. Modern pathology : an official journal of the United States and Canadian Academy of Pathology, Inc, 35(Suppl 1), 8–14. https://doi.org/10.1038/s41379-021-00889-5
#
# ‌
#
# ‌
